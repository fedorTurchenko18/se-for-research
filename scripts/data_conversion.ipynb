# %%
import pandas as pd

# %%
df = pd.read_csv('../data/EEG-Eye-State.csv')

# %%
df.sample(5, random_state=42).to_csv('../tests/data/sample_EEG-Eye-State.csv', index=False)
df.sample(5, random_state=42).to_excel('../tests/data/sample_EEG-Eye-State.xlsx', index=False)
df.sample(5, random_state=42).to_json('../tests/data/sample_EEG-Eye-State.json', orient='records', lines=True)

# %%
cm = pd.read_csv('../tests/data/cm.csv')

# %%
cm.values
# Out:
# array([[85, 15],
#        [12, 88]])
